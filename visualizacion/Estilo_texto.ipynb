# %%
import pandas as pd
df = pd.read_csv("datos/tiendas_procesado.csv", index_col="fecha")
df
# Out:
#              DAIRY          MEATS       SEAFOOD
# fecha
# 2015-01  1134521.0  543117.728891  40465.835012
# 2015-02  1020747.0  498735.076839  36066.561003
# 2015-03  1234851.0  546517.159221  43808.473074
# 2015-04  1181180.0  522304.280744  39983.471003
# 2015-05  1293308.0  591691.899734  42506.832015
# 2015-06  1243588.0  565014.130035  38780.552004
# 2015-07  1244815.0  594903.677368  38535.588006
# 2015-08  1263428.0  581214.143026  37767.580998
# 2015-09  1224619.0  562711.633157  41906.374010
# 2015-10  1314827.0  580788.361242  41423.962963
# 2015-11  1283672.0  535908.927954  38823.761011
# 2015-12  1394582.0  567381.391078  33728.276973

# %%
import matplotlib.pyplot as plt

# %%
plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5),
    title="Venta de 3 tipos de productos en el año 2015"
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)"
)
# Out:
# Text(0, 0.5, 'Ventas (en millones de dólares)')

# %%
# personalizar el texto del título

plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5)
)

ax.set_title(
    "Ventas de 3 productos para el año 2015",
    fontdict={
        "size": 50
    }
)

ax.set_yticks(
    [500000, 1000000]
)

ax.set_yticklabels(
    ["500000", "1000000"]
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)"
)
# Out:
# Text(0, 0.5, 'Ventas (en millones de dólares)')

# %%
# personalizar el texto del título

plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5)
)

ax.set_title(
    "Ventas de 3 productos para el año 2015",
    fontdict={
        "size": 20
    }
)

ax.set_yticks(
    [500000, 1000000]
)

ax.set_yticklabels(
    ["500000", "1000000"]
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)"
)
# Out:
# Text(0, 0.5, 'Ventas (en millones de dólares)')

# %%
# personalizar el texto del título

plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5)
)

ax.set_title(
    "Ventas de 3 productos para el año 2015",
    fontdict={
        "size": 20,
        "weight": "bold"
    }
)

ax.set_yticks(
    [500000, 1000000]
)

ax.set_yticklabels(
    ["500000", "1000000"]
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)"
)
# Out:
# Text(0, 0.5, 'Ventas (en millones de dólares)')

# %%
# personalizar el texto del título

plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5)
)

ax.set_title(
    "Ventas de 3 productos para el año 2015",
    fontdict={
        "size": 20,
        "weight": "bold"
    }
)

ax.set_yticks(
    [500000, 1000000]
)

ax.set_yticklabels(
    ["500000", "1000000"]
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)",
    fontdict={
        "size": 20,
        "name": "Comic Sans MS",
        "color": "red"
    }
)
# Out:
# Text(0, 0.5, 'Ventas (en millones de dólares)')

# %%
# personalizar el texto del título
import numpy as np
plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5)
)

ax.set_title(
    "Ventas de 3 productos para el año 2015",
    fontdict={
        "size": 20,
        "weight": "bold"
    }
)

ax.set_yticks(
    [500000, 1000000]
)

ax.set_yticklabels(
    ["500000", "1000000"],
    fontdict={
        "size":10
    }
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)",
    fontdict={
        "size": 20,
        "name": "Comic Sans MS",
        "color": "red"
    }
)

ax.set_xticks(np.arange(0, len(df)))
ax.set_xticklabels(
    df.index.values,
    fontdict={
        "color": "blue",
        "name": "serif",
        "weight": "bold",
        "size": 8
    }
);

# %%
plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 5)
)

ax.set_title(
    "Ventas de 3 productos para el año 2015",
    fontdict={
        "size": 20,
        "weight": "bold"
    }
)

ax.set_xlabel(
    "Periodo"
)

ax.set_ylabel(
    "Ventas (en millones de dólares)",
    fontdict={
        "size": 20,
        "name": "Comic Sans MS",
        "color": "red"
    }
)

plt.yticks(
    color="blue"
)

plt.xticks(
    color="green"
);

# %%
# plotly
import plotly.express as px

# %%
fig = px.line(
    df,
    width=800,
    height=500,
    template="ggplot2",
    title="Ventas de 3 tipos de productos para el 2015"
)

fig.update_layout(
    xaxis_title="Periodo",
    yaxis_title="Ventas en millones de USD",
    font_color="blue",
    font_family="Courier new"
)

fig.update_xaxes(
    tickangle=45,
    tickvals=df.index.values,
    tickmode="array"
)

fig.update_yaxes(
    dtick=250000
)

fig.show()

# %%
fig = px.line(
    df,
    width=800,
    height=500,
    template="ggplot2",
    title="Ventas de 3 tipos de productos para el 2015"
)

fig.update_layout(
    xaxis_title="Periodo",
    yaxis_title="Ventas en millones de USD", # global
    font_color="blue",
    font_family="Courier new",
    legend_font_color="green",
    legend_title_font_color="red",
    title_font_color="violet",
    title_font_family="Times new roman"
)

fig.update_xaxes(
    tickangle=45,
    tickvals=df.index.values, # para cada eje
    tickmode="array",
    title_font_family="Arial",
    title_font_color="black",
    title_font_size=26,
    tickfont={
        "family": "Rockwell",
        "color": "brown",
        "size": 10
    }
)

fig.update_yaxes(
    dtick=250000
)

fig.show()
