# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style("whitegrid")

# %%
df = pd.read_csv("datos/pinguinos.csv")
df = df.dropna()
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.plot.scatter(
    x="flipper_length_mm",
    y="culmen_length_mm"
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>

# %%
sns.jointplot(
    data=df,
    x="flipper_length_mm",
    y="culmen_length_mm",
    kind="hist"
)

# %%
sns.jointplot(
    data=df,
    x="flipper_length_mm",
    y="culmen_length_mm",
    kind="hist",
    joint_kws={
        "bins": 30
    }
)

# %%
sns.jointplot(
    data=df,
    x="flipper_length_mm",
    y="culmen_length_mm",
    kind="hist",
    joint_kws={
        "bins": 30
    },
    cbar=True
)

# %%
sns.jointplot(
    data=df,
    x="flipper_length_mm",
    y="culmen_length_mm",
    kind="hist",
    joint_kws={
        "bins": 30
    },
    cbar=True,
    marginal_kws={
        "bins": 30,
        "fill": False
    }
)

# %%
sns.jointplot(
    data=df,
    x="flipper_length_mm",
    y="culmen_length_mm",
    kind="hex",
    joint_kws={
        "bins": 30
    },
    marginal_kws={
        "bins": 30,
        "fill": False
    },
    gridsize=30
)

# %%
df.plot.hexbin(
    x="flipper_length_mm",
    y="culmen_length_mm", 
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>

# %% [markdown]
# ## heatmap categorico

# %%
df = pd.read_csv("datos/tienda_ventas.csv")
df = df.dropna()
df
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 2161561  2161561  2016-04-30          9                     POULTRY
# 2161562  2161562  2016-04-30          9              PREPARED FOODS
# 2161563  2161563  2016-04-30          9                     PRODUCE
# 2161564  2161564  2016-04-30          9  SCHOOL AND OFFICE SUPPLIES
# 2161565  2161565  2016-04-30          9                     SEAFOOD
#
#               sales  onpromotion
# 0           0.00000            0
# 1           0.00000            0
# 2           0.00000            0
# ...

# %%
df["Periodo"] = df["date"].apply(lambda x: x[0:7])
df
# Out:
#               id        date  store_nbr                      family  \
# 0              0  2013-01-01          1                  AUTOMOTIVE
# 1              1  2013-01-01          1                   BABY CARE
# 2              2  2013-01-01          1                      BEAUTY
# 3              3  2013-01-01          1                   BEVERAGES
# 4              4  2013-01-01          1                       BOOKS
# ...          ...         ...        ...                         ...
# 2161561  2161561  2016-04-30          9                     POULTRY
# 2161562  2161562  2016-04-30          9              PREPARED FOODS
# 2161563  2161563  2016-04-30          9                     PRODUCE
# 2161564  2161564  2016-04-30          9  SCHOOL AND OFFICE SUPPLIES
# 2161565  2161565  2016-04-30          9                     SEAFOOD
#
#               sales  onpromotion  Periodo
# 0           0.00000            0  2013-01
# 1           0.00000            0  2013-01
# ...

# %%
df2 = df[df["store_nbr"].isin([4, 54, 55, 56, 57, 58, 59])]
df2
# Out:
#               id        date  store_nbr                      family    sales  \
# 1089        1089  2013-01-01          4                  AUTOMOTIVE    0.000
# 1090        1090  2013-01-01          4                   BABY CARE    0.000
# 1091        1091  2013-01-01          4                      BEAUTY    0.000
# 1092        1092  2013-01-01          4                   BEVERAGES    0.000
# 1093        1093  2013-01-01          4                       BOOKS    0.000
# ...          ...         ...        ...                         ...      ...
# 2161429  2161429  2016-04-30         54                     POULTRY   56.629
# 2161430  2161430  2016-04-30         54              PREPARED FOODS   53.000
# 2161431  2161431  2016-04-30         54                     PRODUCE  684.684
# 2161432  2161432  2016-04-30         54  SCHOOL AND OFFICE SUPPLIES   25.000
# 2161433  2161433  2016-04-30         54                     SEAFOOD    3.000
#
#          onpromotion  Periodo
# ...

# %%
df_agrupado = df[df["store_nbr"].isin([3, 44, 45, 46, 47, 48, 49, 50])].groupby(["Periodo", "store_nbr"]).agg({
    "sales": "sum"
})
df_agrupado
# Out:
#                           sales
# Periodo store_nbr
# 2013-01 3          4.965743e+05
#         44         6.763951e+05
#         45         5.394207e+05
#         46         4.851985e+05
#         47         5.328300e+05
# ...                         ...
# 2016-04 46         9.085644e+05
#         47         1.158896e+06
#         48         7.901695e+05
#         49         1.100845e+06
#         50         6.022959e+05
#
# [320 rows x 1 columns]

# %%
df_agrupado.unstack().droplevel(0, axis=1)
# Out:
# store_nbr            3             44            45            46  \
# Periodo
# 2013-01    4.965743e+05  6.763951e+05  5.394207e+05  4.851985e+05
# 2013-02    4.296186e+05  5.955276e+05  5.034798e+05  4.469718e+05
# 2013-03    5.316862e+05  6.973039e+05  6.015846e+05  5.316344e+05
# 2013-04    5.120721e+05  6.669542e+05  5.572005e+05  4.865555e+05
# 2013-05    5.181973e+05  6.726814e+05  5.764108e+05  5.023400e+05
# 2013-06    5.443877e+05  6.663036e+05  5.914544e+05  5.101676e+05
# 2013-07    5.173358e+05  6.375686e+05  5.542560e+05  4.807294e+05
# 2013-08    5.325380e+05  6.541044e+05  5.657099e+05  5.007798e+05
# 2013-09    5.530405e+05  6.857152e+05  5.858765e+05  5.159002e+05
# 2013-10    5.491298e+05  6.645889e+05  5.797002e+05  5.051654e+05
# 2013-11    5.783989e+05  7.927187e+05  6.321858e+05  5.404963e+05
# 2013-12    6.996817e+05  9.174606e+05  8.115263e+05  7.357556e+05
# 2014-01    9.964937e+05  1.241684e+06  1.042211e+06  7.642202e+05
# ...

# %%
df_final = df_agrupado.unstack().droplevel(0, axis=1).transpose()
df_final
# Out:
# Periodo          2013-01        2013-02        2013-03        2013-04  \
# store_nbr
# 3          496574.280985  429618.648974  531686.223879  512072.124974
# 44         676395.138954  595527.551012  697303.868000  666954.222780
# 45         539420.676079  503479.819965  601584.635970  557200.458882
# 46         485198.490116  446971.842070  531634.404456  486555.474044
# 47         532830.024953  477916.973850  578854.175901  524800.597078
# 48         393039.644168  369976.821263  447756.715286  413425.020003
# 49         291891.128982  258320.141966  325003.586018  312894.258091
# 50         341249.754079  323027.227966  374337.286047  348366.691837
#
# Periodo          2013-05        2013-06        2013-07        2013-08  \
# store_nbr
# 3          518197.344186  544387.722974  517335.848845  532537.992913
# 44         672681.377906  666303.585030  637568.579971  654104.371982
# 45         576410.815940  591454.381316  554255.958018  565709.937040
# ...

# %%
sns.heatmap(
    data=df_final,
    cmap="Blues"
)
# Out:
# <Axes: xlabel='Periodo', ylabel='store_nbr'>

# %%
sns.heatmap(
    data=df_final,
    cmap="Blues",
    square=True
)
# Out:
# <Axes: xlabel='Periodo', ylabel='store_nbr'>

# %%
plt.figure(
    figsize=(15, 8)
)
sns.heatmap(
    data=df_final,
    cmap="Blues",
    square=True
)
# Out:
# <Axes: xlabel='Periodo', ylabel='store_nbr'>

# %%
plt.figure(
    figsize=(15, 8)
)
sns.heatmap(
    data=df_final,
    cmap="Blues",
    square=True,
    linewidth=0.1
)
# Out:
# <Axes: xlabel='Periodo', ylabel='store_nbr'>

# %%
plt.figure(
    figsize=(15, 8)
)
sns.heatmap(
    data=df_final,
    cmap="Blues",
    square=True,
    linewidth=0.1,
    annot=True
)
# Out:
# <Axes: xlabel='Periodo', ylabel='store_nbr'>

# %% [markdown]
# ## Heatmap correlaciones

# %%
df = pd.read_csv("datos/pinguinos.csv")
df = df.dropna()
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
matriz = df[["culmen_length_mm", "culmen_depth_mm", "flipper_length_mm", "body_mass_g"]].corr()
matriz
# Out:
#                    culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# culmen_length_mm           1.000000        -0.228640           0.652126
# culmen_depth_mm           -0.228640         1.000000          -0.578730
# flipper_length_mm          0.652126        -0.578730           1.000000
# body_mass_g                0.589066        -0.472987           0.873211
#
#                    body_mass_g
# culmen_length_mm      0.589066
# culmen_depth_mm      -0.472987
# flipper_length_mm     0.873211
# body_mass_g           1.000000

# %%
sns.heatmap(
    matriz, 
    cmap="Blues",
    square=True,
    annot=True
)
# Out:
# <Axes: >

# %%
# paletas divergentes
sns.heatmap(
    matriz, 
    cmap="vlag",
    square=True,
    annot=True
)
# Out:
# <Axes: >

# %%
sns.heatmap(
    matriz, 
    cmap="vlag_r",
    square=True,
    annot=True
)
# Out:
# <Axes: >

# %%
sns.heatmap(
    matriz, 
    cmap="coolwarm_r",
    square=True,
    annot=True
)
# Out:
# <Axes: >
