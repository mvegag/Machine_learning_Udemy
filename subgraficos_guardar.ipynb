# %%
import pandas as pd
df = pd.read_csv("datos/tiendas_procesado.csv", index_col="fecha")
df
# Out:
#              DAIRY          MEATS       SEAFOOD
# fecha
# 2015-01  1134521.0  543117.728891  40465.835012
# 2015-02  1020747.0  498735.076839  36066.561003
# 2015-03  1234851.0  546517.159221  43808.473074
# 2015-04  1181180.0  522304.280744  39983.471003
# 2015-05  1293308.0  591691.899734  42506.832015
# 2015-06  1243588.0  565014.130035  38780.552004
# 2015-07  1244815.0  594903.677368  38535.588006
# 2015-08  1263428.0  581214.143026  37767.580998
# 2015-09  1224619.0  562711.633157  41906.374010
# 2015-10  1314827.0  580788.361242  41423.962963
# 2015-11  1283672.0  535908.927954  38823.761011
# 2015-12  1394582.0  567381.391078  33728.276973

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.subplots(3, 5, constrained_layout=True)
# Out:
# (<Figure size 640x480 with 15 Axes>,
#  array([[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]], dtype=object))

# %%
plt.style.use(
    "ggplot"
)

ax = df.plot.line(
    figsize=(10, 4)
)

ax.set_title(
    "Ventas de 3 tipos de productos en el año 2015",
    fontdict={
        "size": 20,
        "weight": "bold",
    }
)

ax.set_xticks(np.arange(0, len(df)))
ax.set_xticklabels(
    df.index.values
)

ax.set_xlabel(
    "Periodo",
    fontdict={
        "color": "black",
        "size": 12
    }
)

ax.set_ylabel(
    "Ventas en millones de dólares",
    fontdict={
        "color": "black",
        "size": 12
    }
)

ax.annotate(
    "Noviembre",
    xy={10, 1250000},
    xytext=(10, 1000000),
    color="grey",
    
)
# Out:
# Text(10, 1000000, 'Noviembre')

# %%
# subplots
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, constrained_layout=True)

# %%
fig.set_size_inches(8, 8)
fig

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    3, 
    1, 
    constrained_layout=True 
)

fig.set_size_inches(8, 7) 
fig.suptitle('Venta de 3 tipos de productos') 
fig.supylabel('Ventas en Millones de Dolares') 
fig.supxlabel('Periodo') 

df.plot.line(
    y='DAIRY',
    ax=ax1, 
    color='blue'
)

df.plot.line(
    y='MEATS',
    ax=ax2,
    color='red'
)
 
df.plot.line(
    y='SEAFOOD',
    ax=ax3,
    color='green'
)
# Out:
# <Axes: xlabel='fecha'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    3, 
    1, 
    constrained_layout=True 
)

fig.set_size_inches(8, 7) 

df.plot.line(
    y='DAIRY',
    ax=ax1, 
    color='blue'
)

df.plot.line(
    y='MEATS',
    ax=ax2,
    color='red'
)
 
df.plot.line(
    y='SEAFOOD',
    ax=ax3,
    color='green'
)

# un solo tick x
ax1.set_xticklabels([])
ax2.set_xticklabels([])

# un solo titulo 
ax1.set_xlabel("")
ax2.set_xlabel("")
ax3.set_xlabel("")

# titulo a la figura
fig.suptitle("Venta de 3 tipos de productos")

# titulos
fig.supylabel("Ventas en millones de dolares")
fig.supxlabel("Periodo")

# titulos subgraficos
ax1.set_title("Lacteos", fontdict={"size":8})
ax2.set_title("Carnes", fontdict={"size":8})
ax3.set_title("Comida de mar", fontdict={"size":8})

ax1.legend().set_visible(False)
ax2.legend().set_visible(False)
ax3.legend().set_visible(False)

# guardar
plt.savefig(
    "ejemplo1.png",
    format="png",
    dpi=1200
)

# %% [markdown]
# ## Seaborn

# %%
import seaborn as sns

fig, (ax1, ax2, ax3) = plt.subplots(
    3, 
    1, 
    constrained_layout=True 
)

plt.title("Ventas de 3 tipos de productos para el año 2015")
plt.xlabel("Periodo")
plt.ylabel("Ventas (en millones de dolares)")

sns.set_style("ticks")
sns.set_theme("paper")

sns.lineplot(
    data=df,
    ax=ax2
)

ax1.axhline(
    1300000,
    linestyle="dashed",
    linewidth=0.7,
    alpha=0.7,
    color="red"
)

ax1.annotate(
    "Umbral",
    xy = (11, 1250000),
    horizontalalignment="center",
    color="red",
    fontstyle="italic",
    alpha=0.8,
    size=8
)

ax1.legend().set_visible(False)
# Out:
# C:\Users\Mateo\AppData\Local\Temp\ipykernel_7652\2117395467.py:39: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(
    3, 
    1, 
    constrained_layout=True 
)

# usar los titulos por subplots
# titulo a la figura
fig.suptitle("Venta de 3 tipos de productos")

# titulos
fig.supylabel("Ventas en millones de dolares")
fig.supxlabel("Periodo")

sns.set_style("ticks")
sns.set_theme("paper")

sns.lineplot(
    data=df,
    ax=ax2
)

ax1.axhline(
    1300000,
    linestyle="dashed",
    linewidth=0.7,
    alpha=0.7,
    color="red"
)

ax1.annotate(
    "Umbral",
    xy = (11, 1250000),
    horizontalalignment="center",
    color="red",
    fontstyle="italic",
    alpha=0.8,
    size=8
)

ax1.legend().set_visible(True)
ax1.legend(bbox_to_anchor=(1.3, 1))

# guardar
plt.savefig(
    "ejemplo2.png",
    format="png",
    #dpi=600,
    bbox_inches="tight" # para que no deje por fuera la leyenda
)
# Out:
# C:\Users\Mateo\AppData\Local\Temp\ipykernel_7652\3492166694.py:41: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#
# C:\Users\Mateo\AppData\Local\Temp\ipykernel_7652\3492166694.py:42: UserWarning:
#
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Plotly

# %%
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
fig = make_subplots(rows=3, cols=1)

fig.append_trace(
    go.Scatter(
        x=df.index.values,
        y=df["DAIRY"],
        name="Lacteos"
    ), row=1, col=1
)

fig.append_trace(
    go.Scatter(
        x=df.index.values,
        y=df["MEATS"],
        name="Carnes"
    ), row=2, col=1
)

fig.append_trace(
    go.Scatter(
        x=df.index.values,
        y=df["SEAFOOD"],
        name="Comida de mar"
    ), row=3, col=1
)

fig.update_layout(
    height=600,
    width=700,
    title="Venta de tres tipos de productos"
)
fig.show()
